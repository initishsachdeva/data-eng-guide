# %%
import pandas as pd

# %% [markdown]
# # if you have a data with missing values

# %%
df = pd.read_csv("05_missing_values.csv", parse_dates= ["day"])
df
# Out:
#          day  temp  windspeed  event
# 0   12-02-24  23.0        6.0   rain
# 1   13-02-24   NaN        8.0  sunny
# 2   14-02-24  24.0        9.0  rainy
# 3   15-02-24   NaN        9.0    NaN
# 4   16-02-24   NaN        NaN   rain
# 5   17-02-24  34.0        NaN  sunny
# 6   18-02-24   NaN        NaN  rainy
# 7   19-02-24  23.0        5.0    NaN
# 8   20-02-24   NaN        5.0   snow
# 9   21-02-24  33.0        5.0   rain
# 10  22-02-24   NaN        5.0  sunny
# 11  23-02-24   NaN        5.0  rainy

# %%
df.set_index('day', inplace = True)
df
# Out:
#           temp  windspeed  event
# day
# 12-02-24  23.0        6.0   rain
# 13-02-24   NaN        8.0  sunny
# 14-02-24  24.0        9.0  rainy
# 15-02-24   NaN        9.0    NaN
# 16-02-24   NaN        NaN   rain
# 17-02-24  34.0        NaN  sunny
# 18-02-24   NaN        NaN  rainy
# 19-02-24  23.0        5.0    NaN
# 20-02-24   NaN        5.0   snow
# 21-02-24  33.0        5.0   rain
# 22-02-24   NaN        5.0  sunny
# 23-02-24   NaN        5.0  rainy

# %% [markdown]
# # replace  all NAN values with some other value using fillna method

# %%
new_df = df.fillna(0)
new_df
# Out:
#           temp  windspeed  event
# day
# 12-02-24  23.0        6.0   rain
# 13-02-24   0.0        8.0  sunny
# 14-02-24  24.0        9.0  rainy
# 15-02-24   0.0        9.0      0
# 16-02-24   0.0        0.0   rain
# 17-02-24  34.0        0.0  sunny
# 18-02-24   0.0        0.0  rainy
# 19-02-24  23.0        5.0      0
# 20-02-24   0.0        5.0   snow
# 21-02-24  33.0        5.0   rain
# 22-02-24   0.0        5.0  sunny
# 23-02-24   0.0        5.0  rainy

# %% [markdown]
# # sometime 0 is not an exactly or correct value to be replaced for NAN values. Therefore if we specifiy diff values for diff cols by using dictionary`

# %%
new_df = df.fillna({
    'temp': 0,
    'windspeed': 0,
    'event': 'no event'
}
)
new_df
# Out:
#           temp  windspeed     event
# day
# 12-02-24  23.0        6.0      rain
# 13-02-24   0.0        8.0     sunny
# 14-02-24  24.0        9.0     rainy
# 15-02-24   0.0        9.0  no event
# 16-02-24   0.0        0.0      rain
# 17-02-24  34.0        0.0     sunny
# 18-02-24   0.0        0.0     rainy
# 19-02-24  23.0        5.0  no event
# 20-02-24   0.0        5.0      snow
# 21-02-24  33.0        5.0      rain
# 22-02-24   0.0        5.0     sunny
# 23-02-24   0.0        5.0     rainy

# %% [markdown]
# # if we want to carry values from previous row

# %%
new_df = df.fillna(method = "ffill")
new_df
# Out:
# C:\Users\nitsachdeva\AppData\Local\Temp\ipykernel_4004\3373491668.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method = "ffill")
#           temp  windspeed  event
# day
# 12-02-24  23.0        6.0   rain
# 13-02-24  23.0        8.0  sunny
# 14-02-24  24.0        9.0  rainy
# 15-02-24  24.0        9.0  rainy
# 16-02-24  24.0        9.0   rain
# 17-02-24  34.0        9.0  sunny
# 18-02-24  34.0        9.0  rainy
# 19-02-24  23.0        5.0  rainy
# 20-02-24  23.0        5.0   snow
# 21-02-24  33.0        5.0   rain
# 22-02-24  33.0        5.0  sunny
# 23-02-24  33.0        5.0  rainy

# %% [markdown]
# # if we want to carry current value to previous empty row, use bfill

# %%
new_df = df.fillna(method = "bfill")
new_df
# Out:
# C:\Users\nitsachdeva\AppData\Local\Temp\ipykernel_4004\1106947944.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method = "bfill")
#           temp  windspeed  event
# day
# 12-02-24  23.0        6.0   rain
# 13-02-24  24.0        8.0  sunny
# 14-02-24  24.0        9.0  rainy
# 15-02-24  34.0        9.0   rain
# 16-02-24  34.0        5.0   rain
# 17-02-24  34.0        5.0  sunny
# 18-02-24  23.0        5.0  rainy
# 19-02-24  23.0        5.0   snow
# 20-02-24  33.0        5.0   snow
# 21-02-24  33.0        5.0   rain
# 22-02-24   NaN        5.0  sunny
# 23-02-24   NaN        5.0  rainy

# %% [markdown]
# # if you want to copy or move values horizontally to empty row, then use axis

# %%
new_df = df.fillna(method = "bfill", axis="columns")
new_df
# Out:
# C:\Users\nitsachdeva\AppData\Local\Temp\ipykernel_4004\3341064444.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method = "bfill", axis="columns")
#            temp windspeed  event
# day
# 12-02-24   23.0       6.0   rain
# 13-02-24    8.0       8.0  sunny
# 14-02-24   24.0       9.0  rainy
# 15-02-24    9.0       9.0    NaN
# 16-02-24   rain      rain   rain
# 17-02-24   34.0     sunny  sunny
# 18-02-24  rainy     rainy  rainy
# 19-02-24   23.0       5.0    NaN
# 20-02-24    5.0       5.0   snow
# 21-02-24   33.0       5.0   rain
# 22-02-24    5.0       5.0  sunny
# 23-02-24    5.0       5.0  rainy

# %% [markdown]
# # if you want copy the values only once , then use limit property

# %%
new_df = df.fillna(method = "ffill", limit = 1)
new_df
# Out:
# C:\Users\nitsachdeva\AppData\Local\Temp\ipykernel_4004\1348438904.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method = "ffill", limit = 1)
#           temp  windspeed  event
# day
# 12-02-24  23.0        6.0   rain
# 13-02-24  23.0        8.0  sunny
# 14-02-24  24.0        9.0  rainy
# 15-02-24  24.0        9.0  rainy
# 16-02-24   NaN        9.0   rain
# 17-02-24  34.0        NaN  sunny
# 18-02-24  34.0        NaN  rainy
# 19-02-24  23.0        5.0  rainy
# 20-02-24  23.0        5.0   snow
# 21-02-24  33.0        5.0   rain
# 22-02-24  33.0        5.0  sunny
# 23-02-24   NaN        5.0  rainy

# %% [markdown]
# # if you want to get close values bw 2 diff cells like temp A = 20, B= NAN, C= 25 the B might be having value bw 20-25 ,use interpolate method. By default it will show result in linear

# %%
new_df = df.interpolate()
new_df
# Out:
# C:\Users\nitsachdeva\AppData\Local\Temp\ipykernel_4004\812076388.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate()
#                temp  windspeed  event
# day
# 12-02-24  23.000000        6.0   rain
# 13-02-24  23.500000        8.0  sunny
# 14-02-24  24.000000        9.0  rainy
# 15-02-24  27.333333        9.0    NaN
# 16-02-24  30.666667        8.0   rain
# 17-02-24  34.000000        7.0  sunny
# 18-02-24  28.500000        6.0  rainy
# 19-02-24  23.000000        5.0    NaN
# 20-02-24  28.000000        5.0   snow
# 21-02-24  33.000000        5.0   rain
# 22-02-24  33.000000        5.0  sunny
# 23-02-24  33.000000        5.0  rainy

# %%
new_df = df.interpolate(method="time")
new_df
# Out:
# C:\Users\nitsachdeva\AppData\Local\Temp\ipykernel_4004\3296454784.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate(method="time")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 new_df = df.interpolate(method="time")
#       2 new_df
#
# File c:\Users\nitsachdeva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:8203, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8201 else:
#    8202     index = missing.get_interp_index(method, obj.index)
# -> 8203     new_data = obj._mgr.interpolate(
#    8204         method=method,
#    8205         index=index,
#    8206         limit=limit,
#    8207         limit_direction=limit_direction,
#    8208         limit_area=limit_area,
#    8209         inplace=inplace,
#    8210         downcast=downcast,
#    8211         **kwargs,
#    8212     )
#    8214 result = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    8215 if should_transpose:
#
# File c:\Users\nitsachdeva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\base.py:265, in DataManager.interpolate(self, inplace, **kwargs)
#     264 def interpolate(self, inplace: bool, **kwargs) -> Self:
# --> 265     return self.apply_with_block(
#     266         "interpolate", inplace=inplace, **kwargs, using_cow=using_copy_on_write()
#     267     )
#
# File c:\Users\nitsachdeva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\nitsachdeva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\blocks.py:1507, in Block.interpolate(self, method, index, inplace, limit, limit_direction, limit_area, downcast, using_cow, **kwargs)
#    1504 copy, refs = self._get_refs_and_copy(using_cow, inplace)
#    1506 # Dispatch to the EA method.
# -> 1507 new_values = self.array_values.interpolate(
#    1508     method=method,
#    1509     axis=self.ndim - 1,
#    1510     index=index,
#    1511     limit=limit,
#    1512     limit_direction=limit_direction,
#    1513     limit_area=limit_area,
#    1514     copy=copy,
#    1515     **kwargs,
#    1516 )
#    1517 data = extract_array(new_values, extract_numpy=True)
#    1519 nb = self.make_block_same_class(data, refs=refs)
#
# File c:\Users\nitsachdeva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\numpy_.py:297, in NumpyExtensionArray.interpolate(self, method, axis, index, limit, limit_direction, limit_area, copy, **kwargs)
#     294     out_data = self._ndarray.copy()
#     296 # TODO: assert we have floating dtype?
# --> 297 missing.interpolate_2d_inplace(
#     298     out_data,
#     299     method=method,
#     300     axis=axis,
#     301     index=index,
#     302     limit=limit,
#     303     limit_direction=limit_direction,
#     304     limit_area=limit_area,
#     305     **kwargs,
#     306 )
#     307 if not copy:
#     308     return self
#
# File c:\Users\nitsachdeva\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\missing.py:334, in interpolate_2d_inplace(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     332 if method == "time":
#     333     if not needs_i8_conversion(index.dtype):
# --> 334         raise ValueError(
#     335             "time-weighted interpolation only works "
#     336             "on Series or DataFrames with a "
#     337             "DatetimeIndex"
#     338         )
#     339     method = "values"
#     341 limit_direction = validate_limit_direction(limit_direction)
#
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex

# %% [markdown]
# # if you want to drop na values, use dropna.By defaul it will drop all the rows which has Na values.

# %%
new_df = df.dropna()
new_df
# Out:
#           temp  windspeed  event
# day
# 12-02-24  23.0        6.0   rain
# 14-02-24  24.0        9.0  rainy
# 21-02-24  33.0        5.0   rain

# %% [markdown]
# # but if you want to preserve some rows which has atleast 1 data values

# %%
new_df = df.dropna(thresh=2)
new_df
# Out:
#           temp  windspeed  event
# day
# 12-02-24  23.0        6.0   rain
# 13-02-24   NaN        8.0  sunny
# 14-02-24  24.0        9.0  rainy
# 17-02-24  34.0        NaN  sunny
# 19-02-24  23.0        5.0    NaN
# 20-02-24   NaN        5.0   snow
# 21-02-24  33.0        5.0   rain
# 22-02-24   NaN        5.0  sunny
# 23-02-24   NaN        5.0  rainy
